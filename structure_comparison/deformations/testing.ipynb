# %%
#Importing
import librosa
import numpy as np
import scipy
from scipy.spatial.distance import pdist, squareform
from scipy.interpolate import interp2d
from scipy.sparse.csgraph import laplacian
from scipy.spatial.distance import directed_hausdorff
from scipy.cluster import hierarchy
from scipy.linalg import eigh
from scipy.ndimage import median_filter
import cv2
from sklearn import metrics
import matplotlib.pyplot as plt
import dill
import sys
import glob
import os

# %%
dill.load_session('../../../dills/deformations_all.db')

# %%
s = struct['beatles+1+11-Yesterday']['S15S'][0]
s2 = struct['beatles+1+11-Yesterday']['S07S'][0]
fig, axs = plt.subplots(1, kmax-kmin, figsize=(20, 20))
for i in range(kmax-kmin):
    axs[i].matshow(s[i]-s2[i])
plt.show()

# %%
s = struct['beatles+1+11-Yesterday']['T03E'][0]
fig, axs = plt.subplots(1, kmax-kmin, figsize=(20, 20))
for i in range(kmax-kmin):
    axs[i].matshow(s[i])
plt.show()

# %%
s = struct['beatles+1+11-Yesterday']['OG'][0]
fig, axs = plt.subplots(1, kmax-kmin, figsize=(20, 20))
for i in range(kmax-kmin):
    axs[i].matshow(s[i])
plt.show()
